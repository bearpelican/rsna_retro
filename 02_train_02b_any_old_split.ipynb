# %%
from rsna_retro.imports import *
from rsna_retro.metadata import *
from rsna_retro.preprocess import *
from rsna_retro.train import *
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ashaw/.kaggle/kaggle.json'

# %%
torch.cuda.set_device(3)

# %%
df_any.head()
# Out:
#                Modality    PatientID StudyInstanceUID SeriesInstanceUID  \
# SOPInstanceUID
# ID_2a8702d25         CT  ID_ff137633    ID_d17053848c     ID_7098f7c836
# ID_66891ac22         CT  ID_42940b2c    ID_17e33f43d0     ID_e14dd0090b
# ID_8e6e5b51f         CT  ID_76fbed32    ID_1d8eaa14ef     ID_e3919709a0
# ID_cb8b9b514         CT  ID_20039b63    ID_1cfe3e70dd     ID_e3b5d8d9b8
# ID_ee683911f         CT  ID_a065f3ac    ID_9c727ac231     ID_99e83a310d
#
#                StudyID  ImagePositionPatient  ImageOrientationPatient  \
# SOPInstanceUID
# ID_2a8702d25                     -126.437378                      1.0
# ID_66891ac22                     -125.000000                      1.0
# ID_8e6e5b51f                     -125.000000                      1.0
# ID_cb8b9b514                     -125.000000                      1.0
# ID_ee683911f                     -125.000000                      1.0
#
#                 SamplesPerPixel PhotometricInterpretation  Rows  ...  \
# SOPInstanceUID                                                   ...
# ID_2a8702d25                  1               MONOCHROME2   512  ...
# ID_66891ac22                  1               MONOCHROME2   512  ...
# ID_8e6e5b51f                  1               MONOCHROME2   512  ...
# ID_cb8b9b514                  1               MONOCHROME2   512  ...
# ID_ee683911f                  1               MONOCHROME2   512  ...
#
#                 MultiWindowCenter  WindowCenter1  MultiWindowWidth  \
# SOPInstanceUID
# ID_2a8702d25                  NaN            NaN               NaN
# ID_66891ac22                  NaN            NaN               NaN
# ID_8e6e5b51f                  NaN            NaN               NaN
# ID_cb8b9b514                  NaN            NaN               NaN
# ID_ee683911f                  1.0           40.0               1.0
#
#                 WindowWidth1  any  epidural  intraparenchymal  \
# SOPInstanceUID
# ID_2a8702d25             NaN    1         0                 1
# ID_66891ac22             NaN    1         0                 1
# ID_8e6e5b51f             NaN    1         0                 0
# ID_cb8b9b514             NaN    0         0                 0
# ID_ee683911f            80.0    0         0                 0
#
#                 intraventricular  subarachnoid  subdural
# SOPInstanceUID
# ID_2a8702d25                   1             0         0
# ID_66891ac22                   0             0         0
# ID_8e6e5b51f                   0             0         1
# ID_cb8b9b514                   0             0         0
# ID_ee683911f                   0             0         0
#
# [5 rows x 47 columns]

# %%
fns = L(list(df_any.index))

# %%
def get_data(fns, bs, sz, img_dir='nocrop_jpg', splits=splits_any):
    if sz <= 256: img_dir = f'{img_dir}256'
    return get_data_gen(fns, bs=bs, img_tfm=get_pil_fn(path/img_dir), 
                        sz=sz, splits=splits)

# %% [markdown]
# ## Training

# %%
name = 'baseline_any_old_split'

# %%
dbch = get_data(fns, 512, 128)
learn = get_learner(dbch, xresnet34)

# %% [markdown]
# ## Training

# %%
do_fit(learn, 20, 4e-2, freeze=False)
learn.save(f'runs/{name}-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>accuracy_any</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.125344</td>
#       <td>0.160351</td>
#       <td>0.946506</td>
#       <td>0.904517</td>
#       <td>07:48</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.120777</td>
#       <td>0.162023</td>
#       <td>0.945569</td>
#       <td>0.902919</td>
#       <td>07:49</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.116668</td>
#       <td>0.165078</td>
#       <td>0.945192</td>
#       <td>0.903132</td>
#       <td>07:48</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.113016</td>
#       <td>0.168518</td>
#       <td>0.944996</td>
#       <td>0.902440</td>
#       <td>07:48</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.105742</td>
#       <td>0.170850</td>
#       <td>0.945236</td>
#       <td>0.902999</td>
#       <td>07:51</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.100694</td>
#       <td>0.173726</td>
#       <td>0.944903</td>
#       <td>0.901774</td>
#       <td>07:51</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.096744</td>
#       <td>0.177280</td>
#       <td>0.944805</td>
#       <td>0.901614</td>
#       <td>07:50</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.092842</td>
#       <td>0.180514</td>
#       <td>0.944290</td>
#       <td>0.900202</td>
#       <td>07:48</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.093805</td>
#       <td>0.180456</td>
#       <td>0.944566</td>
#       <td>0.900602</td>
#       <td>07:48</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load(f'runs/{name}-2')

# %%
fns_full = L(list(df_comb.index))
learn.dbunch = get_data(fns_full, 512, 256, splits=splits)
do_fit(learn, 2, 1e-4, freeze=False)
learn.save(f'runs/{name}-2b')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>accuracy_any</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.054773</td>
#       <td>0.053839</td>
#       <td>0.982874</td>
#       <td>0.967733</td>
#       <td>20:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.053222</td>
#       <td>05:25</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-773ede523524> in <module>
#       1 fns_full = L(list(df_comb.index))
#       2 learn.dbunch = get_data(fns_full, 512, 256, splits=splits)
# ----> 3 do_fit(learn, 2, 1e-4, freeze=False)
#       4 learn.save(f'runs/{name}-2b')
#
# ~/kaggle/rsna_retro/rsna_retro/train.py in do_fit(learn, epochs, lr, freeze, do_slice, **kwargs)
#      90         learn.fit_one_cycle(1, lr, div=2, div_final=1, pct_start=0.1)
#      91     learn.unfreeze()
# ---> 92     learn.fit_one_cycle(epochs, lr, **kwargs)
#      93
#      94 #Cell
#
# ~/fastai2/fastai2/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#      92     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#      93               'mom': combined_cos(pct_start, *moms)}
# ---> 94     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#      95
#      96 #Cell
#
# ~/fastai2/fastai2/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     278                     try:
#     279                         self.epoch=epoch;          self('begin_epoch')
# --> 280                         self._do_epoch_train()
#     281                         self._do_epoch_validate()
#     282                     except CancelEpochException:   self('after_cancel_epoch')
#
# ~/fastai2/fastai2/learner.py in _do_epoch_train(self)
#     253         try:
#     254             self.dl = self.dbunch.train_dl;                  self('begin_train')
# --> 255             self.all_batches()
#     256         except CancelTrainException:                         self('after_cancel_train')
#     257         finally:                                             self('after_train')
#
# ~/fastai2/fastai2/learner.py in all_batches(self)
#     231     def all_batches(self):
#     232         self.n_iter = len(self.dl)
# --> 233         for o in enumerate(self.dl): self.one_batch(*o)
#     234
#     235     def one_batch(self, i, b):
#
# ~/fastai2/fastai2/learner.py in one_batch(self, i, b)
#     241             self.loss = self.loss_func(self.pred, *self.yb); self('after_loss')
#     242             if not self.training: return
# --> 243             self.loss.backward();                            self('after_backward')
#     244             self.opt.step();                                 self('after_step')
#     245             self.opt.zero_grad()
#
# ~/fastai2/fastai2/learner.py in __call__(self, event_name)
#     212     def ordered_cbs(self, cb_func:str): return [cb for cb in sort_by_run(self.cbs) if hasattr(cb, cb_func)]
#     213
# --> 214     def __call__(self, event_name): L(event_name).map(self._call_one)
#     215     def _call_one(self, event_name):
#     216         assert hasattr(event, event_name)
#
# ~/fastcore/fastcore/foundation.py in map(self, f, *args, **kwargs)
#     360              else f.format if isinstance(f,str)
#     361              else f.__getitem__)
# --> 362         return self._new(map(g, self))
#     363
#     364     def filter(self, f, negate=False, **kwargs):
#
# ~/fastcore/fastcore/foundation.py in _new(self, items, *args, **kwargs)
#     313     @property
#     314     def _xtra(self): return None
# --> 315     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
#     316     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     317     def copy(self): return self._new(self.items.copy())
#
# ~/fastcore/fastcore/foundation.py in __call__(cls, x, *args, **kwargs)
#      39             return x
#      40
# ---> 41         res = super().__call__(*((x,) + args), **kwargs)
#      42         res._newchk = 0
#      43         return res
#
# ~/fastcore/fastcore/foundation.py in __init__(self, items, use_list, match, *rest)
#     304         if items is None: items = []
#     305         if (use_list is not None) or not _is_array(items):
# --> 306             items = list(items) if use_list else _listify(items)
#     307         if match is not None:
#     308             if is_coll(match): match = len(match)
#
# ~/fastcore/fastcore/foundation.py in _listify(o)
#     240     if isinstance(o, list): return o
#     241     if isinstance(o, str) or _is_array(o): return [o]
# --> 242     if is_iter(o): return list(o)
#     243     return [o]
#     244
#
# ~/fastcore/fastcore/foundation.py in __call__(self, *args, **kwargs)
#     206             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     207         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 208         return self.fn(*fargs, **kwargs)
#     209
#     210 #Cell
#
# ~/fastai2/fastai2/learner.py in _call_one(self, event_name)
#     215     def _call_one(self, event_name):
#     216         assert hasattr(event, event_name)
# --> 217         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     218
#     219     def _bn_bias_state(self, with_bias): return bn_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/fastai2/fastai2/learner.py in <listcomp>(.0)
#     215     def _call_one(self, event_name):
#     216         assert hasattr(event, event_name)
# --> 217         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     218
#     219     def _bn_bias_state(self, with_bias): return bn_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/fastai2/fastai2/learner.py in __call__(self, event_name)
#      18     def __call__(self, event_name):
#      19         "Call `self.{event_name}` if it's defined"
# ---> 20         if self.run: getattr(self, event_name, noop)()
#      21
#      22     @property
#
# ~/fastai2/fastai2/callback/fp16.py in after_backward(self)
#      97         self.learn.loss /= self.loss_scale #To record the real loss
#      98         #First, check for an overflow
# ---> 99         if self.dynamic and grad_overflow(self.model_pgs):
#     100             self.loss_scale /= self.div_factor
#     101             self.model.zero_grad()
#
# ~/fastai2/fastai2/callback/fp16.py in grad_overflow(pgs)
#      46     for pg in pgs:
#      47         for p in pg:
# ---> 48             if p.grad is not None and test_overflow(p.grad.data): return True
#      49     return False
#      50
#
# ~/fastai2/fastai2/callback/fp16.py in test_overflow(x)
#      39 #Cell
#      40 def test_overflow(x):
# ---> 41     s = float(x.float().sum())
#      42     return (s == float('inf') or s == float('-inf') or s != s)
#      43
#
# KeyboardInterrupt:

# %% [markdown]
# ## Submission

# %%
learn.load(f'runs/{name}-3')
sub_fn = f'subm/{name}'

# %%
learn.dbunch = get_test_data(df_tst, bs=1024, sz=224)
preds,targs = learn.get_preds()

# %%
pred_csv = submission(df_tst, preds, fn=nm)
FileLink(f'{sub_fn}.csv')

# %%
api.competition_submit(f'{nm}.csv', '0.0744,rn34_repl (scl 0.88)', 'rsna-intracranial-hemorrhage-detection')
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ashaw/.kaggle/kaggle.json'
# 100%|██████████| 26.0M/26.0M [00:02<00:00, 9.52MB/s]
# Successfully submitted to RSNA Intracranial Hemorrhage Detection

# %%
api.competitions_submissions_list('rsna-intracranial-hemorrhage-detection')[0]

# %% [markdown]
# ## Export

# %%
#hide
from nbdev.export import notebook2script
notebook2script()
# Out:
# Converted 01_data_01_metadata_stage2.ipynb.
# Converted 01_data_02_preprocess_windows.ipynb.
# Converted 02_train_01_train.ipynb.
# Converted 04_orig_replace_ashaw_refactor.ipynb.
# Converted 04_replace_ashaw_refactor.ipynb.
# Converted 04b_orig_replace_ashaw_refactor.ipynb.
# Converted 10_qure.ipynb.
# Converted 12_merge.ipynb.
# Converted 14_xgboost.ipynb.
# Converted 16_slice_e2e-shallow.ipynb.
# Converted 16b_orig_slice_e2e-shallow.ipynb.
# This cell doesn't have an export destination and was ignored:
# e
# Converted 17_slice_model-deep.ipynb.
# Converted 21_cleanup-nocrop2.ipynb.
# Converted 26_submit_final.ipynb.
# Converted 27_ensemble_tabular_nn.ipynb.
# Converted 99_index.ipynb.
# Converted cleanup-combine-qure.ipynb.
# Converted delete_03b_cleanup-tif.ipynb.
# Converted submit.ipynb.
# Converted walkthru.ipynb.
# Converted x00_tcia-ct-segm-prep.ipynb.
# Converted x00_tcia-ct-segm-train.ipynb.
