# %% [markdown]
# ## RF

# %%
# import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from rsnautils import *

# %%
pkls = L(path_pred.glob('*_tta.pkl'))

# %%
fn = pkls[0]

# %%
def read_preds(fn):
    preds,targs = fn.load()
    df = pd.DataFrame(preds.numpy())
    df.columns = [':'.join([fn.stem[:-4], c]) for c in htypes]
    return df

# %%
get_data = get_rsna_data_func(1, nw=8)
dbch = get_data(128, None, use_wgt=False)

# %%
pred_dfs = pkls.map(read_preds)

# %%
Xdf = pd.concat(pred_dfs, axis=1)

# %%
def split_data(df):
    idx = L.range(df)
    mask = df.index.isin(set(val_sops))
    return idx[~mask],idx[mask]

# %%
preds,targs = fn.load()

# %%
t = targs.numpy()[:-2]

# %%
splits = split_data(df_comb)

# %%
y_valid = df_comb.iloc[splits[1]][htypes]

# %%
np.equal(t, y_valid.values).mean()
# Out:
# 0.8986414202337001

# %%
np.nonzero(t)
# Out:
# (array([    37,     37,     38,     38, ..., 136742, 136742, 136743, 136743]),
#  array([0, 5, 0, 4, ..., 0, 5, 0, 5]))

# %%
np.nonzero(y_valid.values)
# Out:
# (array([   256,    256,    257,    257, ..., 136762, 136762, 136763, 136763]),
#  array([0, 5, 0, 5, ..., 0, 3, 0, 3]))

# %%
loss = get_loss()

# %%
def calc_loss(df):
    ypred = logit(to_device(tensor(df.values)))[:136785]
    targ = to_device(tensor(y_valid))
    return loss(ypred, targ).cpu().item(), accuracy_multi(ypred, targ).cpu().item()

losses= dict(list(zip([fn.stem for fn in pkls], L(pred_dfs).map(calc_loss))))
pd.Series(losses).sort_values()
# Out:
# xserxt18_wgtd_tta                (0.576793372631073, 0.9059083461761475)
# xrn18_wgtd_tta                  (0.5804729461669922, 0.9056243896484375)
# rn18_wgtd_no_pre_tta            (0.5809637308120728, 0.9058936834335327)
# train_rn18_orig_tta             (0.5880447626113892, 0.9056402444839478)
# impre-xrn34-freeze2-deep_tta     (0.597140371799469, 0.9049774408340454)
# impre-xrn34-freeze2_tta         (0.5978264212608337, 0.9049201607704163)
# train_rn18_all_tta              (0.5992218255996704, 0.9053905010223389)
# rn18_wgtd_freeze2_tta           (0.6032768487930298, 0.9054087400436401)
# train_rn34_tta                   (0.603354811668396, 0.9052966237068176)
# xrn34_wgtd_deep_tta             (0.6039314270019531, 0.9047532081604004)
# xrn34_wgtd_deepish_tta          (0.6092332005500793, 0.9053575992584229)
# train_rn50_all_tta              (0.6109864115715027, 0.9048433899879456)
# rn18_wgtd_freeze2_rep_tta       (0.6111599206924438, 0.9053490161895752)
# train_rn18_nofr_tta              (0.6120439171791077, 0.905781626701355)
# xrn34_wgtd_tta                  (0.6125257015228271, 0.9045570492744446)
# impre-xsrxt50-freeze2_tta       (0.6235345005989075, 0.9052065014839172)
# rn18_wgtd_freeze_tta             (0.628032922744751, 0.9048178195953369)
# train_rn34_nofr_tta             (0.6281428933143616, 0.9046106338500977)
# rn18_wgtd_tta                   (0.6422017216682434, 0.9045729041099548)
# rn18_wgtd_hist_tta              (0.6610257029533386, 0.9038345217704773)
# xrn50_wgtd_deep_tta             (0.7124781012535095, 0.9041391015052795)
# xrn50_wgtd_tta                  (0.7165635824203491, 0.9042232036590576)
# train_rn18_tta                   (1.6839237213134766, 0.909876823425293)
# dtype: object

# %%
valid_df = df_comb.loc[y_valid.index]

# %%
set_seed(42)
val_patients = valid_df.PatientID.unique()
np.random.shuffle(val_patients)
split_idx = int(0.8*len(val_patients))
train_p, val_p = val_patients[0:split_idx], val_patients[split_idx:]
train_idx = valid_df.PatientID.isin(train_p).values
val_idx = valid_df.PatientID.isin(val_p).values

train_x  = Xdf.loc[train_idx]
train_y  = y_valid.loc[train_idx]

val_x  = Xdf.loc[val_idx]
val_y  = y_valid.loc[val_idx]

# %%
labels = [l for l in htypes if l != 'any']

# %%
# train label

# %%
def feature_cols(df, label): return [c for c in df.columns if c.split(':')[1] == label]
def model_cols(df, model):   return [c for c in df.columns if c.split(':')[0] == model]

def pull_features(df, label):
    any_cols = feature_cols(df, 'any')
    feat_cols = feature_cols(df, label)
    return df[feat_cols+any_cols]

def pull_any_features(df, model):
    any_cols = feature_cols(df, 'any')
    m_cols = model_cols(df, model)
    cols = list(set(any_cols+m_cols))
    return df[cols]

# %%
def get_data(label, x, y):
    xl = pull_any_features(x, label) if label == 'any' else pull_features(x, label)
    return xl, y[label]

# %%
def train_label(label, x, y):
    print(f'training {label}')
    clf = RandomForestClassifier(n_estimators=100, min_samples_leaf=10, max_features=0.9, n_jobs=16, oob_score=True)
    xl,yl = get_data(label, x, y)
    clf = clf.fit(xl,yl)
    clf.feat_imp_cols = xl.columns
    return clf

# %%
def train(label): return train_label(label, train_x, train_y) 
rfs = { label:train(label) for label in htypes }
# Out:
# training any
# training epidural
# training intraparenchymal
# training intraventricular
# training subarachnoid
# training subdural

# %%
def predict_rfs(rfs, x, labels):
    preds = []
    for label in labels:
        print(f'predict {label}')
        xl = pull_any_features(x, label) if label == 'any' else pull_features(x, label)
        ypred = rfs[label].predict_proba(xl)
        preds.append(ypred[:,1])
    return pd.DataFrame(np.stack(preds).T, index=x.index, columns=labels)

# %%
ypred = predict_rfs(rfs, val_x, htypes)
# Out:
# predict any
# predict epidural
# predict intraparenchymal
# predict intraventricular
# predict subarachnoid
# predict subdural

# %%
yp = tensor(ypred)
p,t = to_device((yp,tensor(val_y.values).float()))

# %%
loss(logit(p),t).item(), accuracy_multi(logit(p), t).item()
# Out:
# (0.06706075370311737, 0.9789391756057739)

# %%
for label in htypes:
    print('')
    print(f'feat importances for {label}')
    print('---------------------------------------------------')
    fis = sorted(zip(map(lambda x: round(x, 4), rfs[label].feature_importances_), rfs[label].feat_imp_cols),  reverse=True)
    for fi in fis:
        print(fi)
# Out:
# feat importances for any
# ---------------------------------------------------
# (0.2813, 'xrn34_wgtd_deepish:any')
# (0.1748, 'train_rn18:any')
# (0.1262, 'xrn34_wgtd_deep:any')
# (0.1187, 'rn18_wgtd_freeze2_rep:any')
# (0.078, 'rn18_wgtd:any')
# (0.0554, 'train_rn18_all:any')
# (0.0368, 'xrn50_wgtd:any')
# (0.0247, 'train_rn18_all_flip:any')
# (0.0076, 'xrn50_wgtd_flip:any')
# (0.0053, 'xrn18_wgtd:any')
# (0.0052, 'xrn18_wgtd_flip:any')
# (0.0051, 'xrn50_wgtd_deep_flip:any')
# (0.0051, 'xrn50_wgtd_deep:any')
# (0.005, 'xrn34_wgtd_deep_flip:any')
# (0.0048, 'train_rn18_flip:any')
# (0.0046, 'rn18_wgtd_hist:any')
# (0.0045, 'xrn34_wgtd_deepish_flip:any')
# (0.0043, 'rn18_wgtd_hist_flip:any')
# (0.0043, 'rn18_wgtd_freeze2:any')
# (0.0043, 'rn18_wgtd_flip:any')
# (0.0042, 'rn18_wgtd_no_pre:any')
# (0.0041, 'xrn34_wgtd_flip:any')
# (0.0038, 'xrn34_wgtd:any')
# (0.0038, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0037, 'impre-xrn34-freeze2:any')
# (0.0036, 'rn18_wgtd_no_pre_flip:any')
# (0.0036, 'rn18_wgtd_freeze:any')
# (0.0036, 'rn18_wgtd_freeze2_flip:any')
# (0.0036, 'impre-xrn34-freeze2-deep:any')
# (0.0034, 'rn18_wgtd_freeze_flip:any')
# (0.0033, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0032, 'impre-xrn34-freeze2_flip:any')
#
# feat importances for epidural
# ---------------------------------------------------
# (0.1042, 'train_rn18:epidural')
# (0.0688, 'train_rn18_flip:epidural')
# (0.0505, 'rn18_wgtd_no_pre:epidural')
# (0.0497, 'rn18_wgtd_freeze_flip:epidural')
# (0.0463, 'xrn34_wgtd:epidural')
# (0.0437, 'rn18_wgtd_freeze2_flip:epidural')
# (0.0337, 'xrn18_wgtd:epidural')
# (0.0285, 'rn18_wgtd_freeze:epidural')
# (0.0224, 'rn18_wgtd_hist:epidural')
# (0.0214, 'rn18_wgtd:epidural')
# (0.0211, 'xrn50_wgtd:epidural')
# (0.0208, 'rn18_wgtd_freeze2:epidural')
# (0.0189, 'train_rn18_all:epidural')
# (0.0179, 'impre-xrn34-freeze2:epidural')
# (0.017, 'xrn34_wgtd_deep:epidural')
# (0.0169, 'rn18_wgtd_hist_flip:epidural')
# (0.0168, 'rn18_wgtd_freeze2_rep:epidural')
# (0.0165, 'xrn34_wgtd_flip:epidural')
# (0.0163, 'rn18_wgtd_no_pre_flip:epidural')
# (0.0159, 'xrn34_wgtd_deep_flip:epidural')
# (0.0159, 'train_rn18_all_flip:epidural')
# (0.0156, 'xrn50_wgtd_flip:epidural')
# (0.0153, 'impre-xrn34-freeze2-deep:epidural')
# (0.0151, 'xrn34_wgtd_deepish:epidural')
# (0.0147, 'xrn18_wgtd_flip:epidural')
# (0.0138, 'xrn50_wgtd_deep:epidural')
# (0.0136, 'impre-xrn34-freeze2-deep_flip:epidural')
# (0.0128, 'impre-xrn34-freeze2_flip:epidural')
# (0.0126, 'rn18_wgtd_flip:epidural')
# (0.0125, 'xrn34_wgtd_deepish_flip:epidural')
# (0.0117, 'xrn50_wgtd:any')
# (0.0101, 'rn18_wgtd_hist:any')
# (0.0091, 'xrn34_wgtd:any')
# (0.009, 'rn18_wgtd_freeze2_rep_flip:epidural')
# (0.0087, 'xrn18_wgtd:any')
# (0.0082, 'xrn34_wgtd_deep:any')
# (0.0078, 'xrn50_wgtd_deep:any')
# (0.0074, 'rn18_wgtd_hist_flip:any')
# (0.0073, 'xrn50_wgtd_deep_flip:epidural')
# (0.007, 'rn18_wgtd_freeze_flip:any')
# (0.0067, 'train_rn18_flip:any')
# (0.0067, 'rn18_wgtd_freeze:any')
# (0.0066, 'xrn50_wgtd_flip:any')
# (0.0062, 'xrn50_wgtd_deep_flip:any')
# (0.006, 'xrn34_wgtd_deepish_flip:any')
# (0.006, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0059, 'impre-xrn34-freeze2:any')
# (0.0057, 'rn18_wgtd_no_pre_flip:any')
# (0.0055, 'rn18_wgtd_flip:any')
# (0.0053, 'xrn34_wgtd_deepish:any')
# (0.0052, 'xrn34_wgtd_flip:any')
# (0.0052, 'impre-xrn34-freeze2_flip:any')
# (0.0052, 'impre-xrn34-freeze2-deep:any')
# (0.005, 'xrn34_wgtd_deep_flip:any')
# (0.005, 'rn18_wgtd_freeze2:any')
# (0.0049, 'train_rn18:any')
# (0.0048, 'rn18_wgtd_freeze2_flip:any')
# (0.0047, 'train_rn18_all:any')
# (0.0046, 'rn18_wgtd:any')
# (0.0044, 'train_rn18_all_flip:any')
# (0.0042, 'rn18_wgtd_no_pre:any')
# (0.0039, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0037, 'xrn18_wgtd_flip:any')
# (0.0036, 'rn18_wgtd_freeze2_rep:any')
#
# feat importances for intraparenchymal
# ---------------------------------------------------
# (0.3324, 'rn18_wgtd_freeze2_rep:intraparenchymal')
# (0.1645, 'xrn34_wgtd_deep_flip:intraparenchymal')
# (0.0693, 'xrn34_wgtd_deepish:intraparenchymal')
# (0.0686, 'rn18_wgtd_freeze2:intraparenchymal')
# (0.0663, 'rn18_wgtd_hist:intraparenchymal')
# (0.0422, 'rn18_wgtd:intraparenchymal')
# (0.0361, 'xrn34_wgtd_deep:intraparenchymal')
# (0.0211, 'rn18_wgtd_hist_flip:intraparenchymal')
# (0.0209, 'impre-xrn34-freeze2:intraparenchymal')
# (0.0163, 'xrn50_wgtd:intraparenchymal')
# (0.0139, 'xrn50_wgtd_deep:intraparenchymal')
# (0.0122, 'xrn50_wgtd_deep_flip:intraparenchymal')
# (0.011, 'rn18_wgtd_freeze2_flip:intraparenchymal')
# (0.0105, 'xrn50_wgtd_flip:intraparenchymal')
# (0.0063, 'train_rn18_all_flip:intraparenchymal')
# (0.0058, 'rn18_wgtd_freeze2_rep_flip:intraparenchymal')
# (0.0057, 'train_rn18_flip:intraparenchymal')
# (0.0053, 'train_rn18_all:intraparenchymal')
# (0.0049, 'impre-xrn34-freeze2-deep:intraparenchymal')
# (0.0048, 'train_rn18:intraparenchymal')
# (0.0038, 'xrn34_wgtd:intraparenchymal')
# (0.0037, 'impre-xrn34-freeze2_flip:intraparenchymal')
# (0.0036, 'xrn34_wgtd_deepish_flip:intraparenchymal')
# (0.0035, 'rn18_wgtd_flip:intraparenchymal')
# (0.0033, 'xrn34_wgtd_flip:intraparenchymal')
# (0.0032, 'rn18_wgtd_freeze:intraparenchymal')
# (0.0029, 'xrn18_wgtd:intraparenchymal')
# (0.0029, 'impre-xrn34-freeze2-deep_flip:intraparenchymal')
# (0.0028, 'rn18_wgtd_no_pre:intraparenchymal')
# (0.0026, 'rn18_wgtd_no_pre_flip:intraparenchymal')
# (0.0026, 'rn18_wgtd_freeze_flip:intraparenchymal')
# (0.0023, 'xrn18_wgtd_flip:intraparenchymal')
# (0.0017, 'xrn50_wgtd:any')
# (0.0017, 'train_rn18_all_flip:any')
# (0.0017, 'train_rn18_all:any')
# (0.0016, 'xrn50_wgtd_flip:any')
# (0.0016, 'xrn50_wgtd_deep:any')
# (0.0016, 'xrn34_wgtd_deepish_flip:any')
# (0.0016, 'xrn34_wgtd_deepish:any')
# (0.0016, 'rn18_wgtd_flip:any')
# (0.0016, 'impre-xrn34-freeze2-deep:any')
# (0.0015, 'xrn18_wgtd:any')
# (0.0015, 'rn18_wgtd_no_pre_flip:any')
# (0.0015, 'rn18_wgtd_freeze:any')
# (0.0015, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0014, 'xrn50_wgtd_deep_flip:any')
# (0.0014, 'xrn34_wgtd_deep_flip:any')
# (0.0014, 'xrn34_wgtd:any')
# (0.0014, 'rn18_wgtd_no_pre:any')
# (0.0014, 'rn18_wgtd_hist_flip:any')
# (0.0014, 'rn18_wgtd:any')
# (0.0014, 'impre-xrn34-freeze2:any')
# (0.0013, 'rn18_wgtd_hist:any')
# (0.0013, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0013, 'rn18_wgtd_freeze2_rep:any')
# (0.0013, 'rn18_wgtd_freeze2:any')
# (0.0012, 'xrn34_wgtd_flip:any')
# (0.0012, 'xrn34_wgtd_deep:any')
# (0.0012, 'xrn18_wgtd_flip:any')
# (0.0012, 'train_rn18_flip:any')
# (0.0012, 'train_rn18:any')
# (0.0012, 'impre-xrn34-freeze2_flip:any')
# (0.0011, 'rn18_wgtd_freeze2_flip:any')
# (0.001, 'rn18_wgtd_freeze_flip:any')
#
# feat importances for intraventricular
# ---------------------------------------------------
# (0.3576, 'xrn50_wgtd_deep:intraventricular')
# (0.3279, 'rn18_wgtd_hist:intraventricular')
# (0.0792, 'xrn50_wgtd_flip:intraventricular')
# (0.0674, 'rn18_wgtd_freeze2_rep:intraventricular')
# (0.0197, 'rn18_wgtd_hist_flip:intraventricular')
# (0.015, 'xrn34_wgtd_deep:intraventricular')
# (0.0117, 'rn18_wgtd_freeze:intraventricular')
# (0.0071, 'rn18_wgtd:intraventricular')
# (0.0066, 'xrn50_wgtd_deep_flip:intraventricular')
# (0.0054, 'xrn34_wgtd_deepish:intraventricular')
# (0.0051, 'xrn50_wgtd:intraventricular')
# (0.0047, 'train_rn18_all:intraventricular')
# (0.0043, 'impre-xrn34-freeze2-deep:intraventricular')
# (0.004, 'xrn34_wgtd_deep_flip:intraventricular')
# (0.0039, 'impre-xrn34-freeze2:intraventricular')
# (0.0039, 'impre-xrn34-freeze2-deep_flip:intraventricular')
# (0.0038, 'rn18_wgtd_no_pre:intraventricular')
# (0.0035, 'impre-xrn34-freeze2_flip:intraventricular')
# (0.0033, 'train_rn18_flip:intraventricular')
# (0.0031, 'rn18_wgtd_freeze2_rep_flip:intraventricular')
# (0.0026, 'train_rn18:intraventricular')
# (0.0026, 'rn18_wgtd_freeze2:intraventricular')
# (0.0024, 'xrn18_wgtd_flip:intraventricular')
# (0.0024, 'train_rn18_all_flip:intraventricular')
# (0.0024, 'rn18_wgtd_freeze_flip:intraventricular')
# (0.0023, 'xrn34_wgtd_flip:intraventricular')
# (0.0023, 'rn18_wgtd_flip:intraventricular')
# (0.0022, 'xrn34_wgtd_deepish_flip:intraventricular')
# (0.0022, 'xrn18_wgtd:intraventricular')
# (0.0022, 'rn18_wgtd_no_pre_flip:intraventricular')
# (0.0022, 'rn18_wgtd_freeze2_flip:intraventricular')
# (0.0019, 'xrn34_wgtd:intraventricular')
# (0.0015, 'xrn50_wgtd_deep:any')
# (0.0015, 'xrn50_wgtd:any')
# (0.0014, 'rn18_wgtd_freeze:any')
# (0.0013, 'train_rn18_all_flip:any')
# (0.0013, 'train_rn18_all:any')
# (0.0012, 'rn18_wgtd_hist_flip:any')
# (0.0012, 'rn18_wgtd_freeze2_rep:any')
# (0.0012, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0011, 'xrn50_wgtd_flip:any')
# (0.0011, 'xrn50_wgtd_deep_flip:any')
# (0.0011, 'xrn34_wgtd_deepish:any')
# (0.0011, 'xrn34_wgtd_deep_flip:any')
# (0.0011, 'rn18_wgtd_no_pre_flip:any')
# (0.0011, 'rn18_wgtd_no_pre:any')
# (0.0011, 'rn18_wgtd_hist:any')
# (0.0011, 'rn18_wgtd_freeze2_flip:any')
# (0.0011, 'rn18_wgtd_flip:any')
# (0.001, 'xrn34_wgtd_deep:any')
# (0.001, 'xrn34_wgtd:any')
# (0.001, 'train_rn18_flip:any')
# (0.001, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.001, 'rn18_wgtd:any')
# (0.001, 'impre-xrn34-freeze2_flip:any')
# (0.001, 'impre-xrn34-freeze2:any')
# (0.001, 'impre-xrn34-freeze2-deep:any')
# (0.0009, 'xrn34_wgtd_flip:any')
# (0.0009, 'xrn18_wgtd_flip:any')
# (0.0009, 'xrn18_wgtd:any')
# (0.0009, 'train_rn18:any')
# (0.0009, 'rn18_wgtd_freeze_flip:any')
# (0.0009, 'rn18_wgtd_freeze2:any')
# (0.0008, 'xrn34_wgtd_deepish_flip:any')
#
# feat importances for subarachnoid
# ---------------------------------------------------
# (0.3557, 'xrn34_wgtd_deep:subarachnoid')
# (0.238, 'xrn34_wgtd_deep_flip:subarachnoid')
# (0.0916, 'rn18_wgtd_freeze2:subarachnoid')
# (0.0227, 'rn18_wgtd_freeze2_rep:subarachnoid')
# (0.0176, 'xrn50_wgtd_deep_flip:subarachnoid')
# (0.0176, 'train_rn18:subarachnoid')
# (0.0172, 'xrn50_wgtd_deep:subarachnoid')
# (0.0151, 'xrn34_wgtd_deepish:subarachnoid')
# (0.0118, 'xrn50_wgtd_flip:subarachnoid')
# (0.0114, 'xrn50_wgtd:subarachnoid')
# (0.0081, 'rn18_wgtd_hist_flip:subarachnoid')
# (0.0074, 'xrn34_wgtd_flip:subarachnoid')
# (0.0074, 'xrn34_wgtd:subarachnoid')
# (0.0071, 'train_rn18_all_flip:subarachnoid')
# (0.0065, 'rn18_wgtd_freeze2_flip:subarachnoid')
# (0.0064, 'rn18_wgtd_no_pre:subarachnoid')
# (0.0064, 'rn18_wgtd_freeze2_rep_flip:subarachnoid')
# (0.0063, 'train_rn18_flip:subarachnoid')
# (0.0063, 'train_rn18_all:subarachnoid')
# (0.0059, 'rn18_wgtd_freeze:subarachnoid')
# (0.0054, 'rn18_wgtd_hist:subarachnoid')
# (0.0052, 'xrn18_wgtd_flip:subarachnoid')
# (0.0052, 'impre-xrn34-freeze2-deep:subarachnoid')
# (0.005, 'xrn34_wgtd_deepish_flip:subarachnoid')
# (0.005, 'impre-xrn34-freeze2_flip:subarachnoid')
# (0.0049, 'rn18_wgtd:subarachnoid')
# (0.0048, 'impre-xrn34-freeze2:subarachnoid')
# (0.0047, 'rn18_wgtd_no_pre_flip:subarachnoid')
# (0.0047, 'rn18_wgtd_freeze_flip:subarachnoid')
# (0.0047, 'impre-xrn34-freeze2-deep_flip:subarachnoid')
# (0.0045, 'xrn18_wgtd:subarachnoid')
# (0.0044, 'rn18_wgtd_flip:subarachnoid')
# (0.0031, 'xrn50_wgtd_deep:any')
# (0.003, 'xrn50_wgtd_deep_flip:any')
# (0.0029, 'impre-xrn34-freeze2:any')
# (0.0028, 'xrn34_wgtd:any')
# (0.0028, 'train_rn18_all_flip:any')
# (0.0027, 'train_rn18_all:any')
# (0.0026, 'xrn50_wgtd:any')
# (0.0026, 'rn18_wgtd_hist_flip:any')
# (0.0025, 'xrn50_wgtd_flip:any')
# (0.0025, 'rn18_wgtd:any')
# (0.0024, 'xrn34_wgtd_flip:any')
# (0.0024, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0023, 'xrn34_wgtd_deepish_flip:any')
# (0.0023, 'xrn34_wgtd_deepish:any')
# (0.0023, 'xrn18_wgtd_flip:any')
# (0.0023, 'xrn18_wgtd:any')
# (0.0023, 'train_rn18:any')
# (0.0023, 'rn18_wgtd_freeze2_rep:any')
# (0.0022, 'train_rn18_flip:any')
# (0.0022, 'rn18_wgtd_hist:any')
# (0.0022, 'rn18_wgtd_freeze:any')
# (0.0022, 'impre-xrn34-freeze2_flip:any')
# (0.0021, 'xrn34_wgtd_deep_flip:any')
# (0.0021, 'xrn34_wgtd_deep:any')
# (0.0021, 'rn18_wgtd_freeze2_flip:any')
# (0.0021, 'rn18_wgtd_flip:any')
# (0.0021, 'impre-xrn34-freeze2-deep_flip:any')
# (0.002, 'rn18_wgtd_no_pre_flip:any')
# (0.002, 'rn18_wgtd_no_pre:any')
# (0.002, 'rn18_wgtd_freeze2:any')
# (0.0019, 'impre-xrn34-freeze2-deep:any')
# (0.0018, 'rn18_wgtd_freeze_flip:any')
#
# feat importances for subdural
# ---------------------------------------------------
# (0.2656, 'xrn34_wgtd_deep:subdural')
# (0.2314, 'train_rn18:subdural')
# (0.1367, 'train_rn18_all:subdural')
# (0.0583, 'xrn34_wgtd_deepish:subdural')
# (0.0183, 'rn18_wgtd:subdural')
# (0.0167, 'xrn34_wgtd:subdural')
# (0.014, 'xrn18_wgtd:subdural')
# (0.0128, 'train_rn18_flip:subdural')
# (0.0126, 'rn18_wgtd_no_pre:subdural')
# (0.0119, 'xrn34_wgtd_deep_flip:subdural')
# (0.0098, 'xrn50_wgtd:subdural')
# (0.0094, 'rn18_wgtd_freeze2:subdural')
# (0.0084, 'xrn50_wgtd_deep_flip:subdural')
# (0.0078, 'train_rn18_all_flip:subdural')
# (0.0074, 'xrn50_wgtd_flip:subdural')
# (0.0074, 'xrn18_wgtd_flip:subdural')
# (0.0072, 'xrn50_wgtd_deep:subdural')
# (0.006, 'rn18_wgtd_no_pre_flip:subdural')
# (0.0059, 'xrn34_wgtd_deepish_flip:subdural')
# (0.0058, 'rn18_wgtd_hist:subdural')
# (0.0055, 'xrn34_wgtd_flip:subdural')
# (0.0055, 'impre-xrn34-freeze2-deep:subdural')
# (0.0054, 'rn18_wgtd_hist_flip:subdural')
# (0.0051, 'rn18_wgtd_freeze:subdural')
# (0.005, 'impre-xrn34-freeze2:subdural')
# (0.0049, 'rn18_wgtd_freeze2_rep:subdural')
# (0.0049, 'rn18_wgtd_flip:subdural')
# (0.0045, 'rn18_wgtd_freeze_flip:subdural')
# (0.0044, 'xrn50_wgtd:any')
# (0.0044, 'rn18_wgtd_freeze2_flip:subdural')
# (0.0044, 'impre-xrn34-freeze2_flip:subdural')
# (0.0043, 'impre-xrn34-freeze2-deep_flip:subdural')
# (0.0042, 'rn18_wgtd_freeze2_rep_flip:subdural')
# (0.0033, 'train_rn18_all_flip:any')
# (0.0032, 'rn18_wgtd_hist:any')
# (0.0031, 'xrn50_wgtd_flip:any')
# (0.0031, 'train_rn18_all:any')
# (0.0029, 'xrn50_wgtd_deep_flip:any')
# (0.0029, 'xrn34_wgtd_flip:any')
# (0.0029, 'xrn34_wgtd_deepish_flip:any')
# (0.0029, 'xrn34_wgtd:any')
# (0.0028, 'train_rn18_flip:any')
# (0.0028, 'rn18_wgtd_hist_flip:any')
# (0.0028, 'rn18_wgtd_freeze:any')
# (0.0028, 'rn18_wgtd:any')
# (0.0028, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0027, 'xrn50_wgtd_deep:any')
# (0.0027, 'xrn34_wgtd_deepish:any')
# (0.0027, 'rn18_wgtd_freeze2:any')
# (0.0027, 'rn18_wgtd_flip:any')
# (0.0027, 'impre-xrn34-freeze2:any')
# (0.0026, 'rn18_wgtd_no_pre:any')
# (0.0026, 'rn18_wgtd_freeze_flip:any')
# (0.0026, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0026, 'rn18_wgtd_freeze2_rep:any')
# (0.0025, 'xrn34_wgtd_deep_flip:any')
# (0.0025, 'xrn34_wgtd_deep:any')
# (0.0025, 'train_rn18:any')
# (0.0025, 'rn18_wgtd_no_pre_flip:any')
# (0.0024, 'xrn18_wgtd:any')
# (0.0024, 'impre-xrn34-freeze2-deep:any')
# (0.0023, 'xrn18_wgtd_flip:any')
# (0.0023, 'impre-xrn34-freeze2_flip:any')
# (0.0022, 'rn18_wgtd_freeze2_flip:any')

# %%
def calc_loss_rf_valid(df):
    ypred = logit(to_device(tensor(df.loc[val_idx].values)))
    targ = to_device(tensor(val_y))
    return loss(ypred, targ).cpu().item(), accuracy_multi(ypred, targ).cpu().item()

losses= dict(list(zip([fn.stem for fn in all_preds], L(pred_dfs).map(calc_loss_rf_valid))))
pd.Series(losses).sort_values()
# Out:
# rn18_wgtd                        (0.06856484711170197, 0.9775579571723938)
# xrn34_wgtd_deep                  (0.06873700767755508, 0.9772636890411377)
# rn18_wgtd_freeze2                (0.06893426924943924, 0.9776120185852051)
# rn18_wgtd_hist                   (0.06914354115724564, 0.9777020812034607)
# xrn34_wgtd                       (0.06921088695526123, 0.9772636890411377)
# xrn34_wgtd_deep_flip             (0.06938355416059494, 0.9772456884384155)
# rn18_wgtd_freeze2_rep            (0.06949618458747864, 0.9775159358978271)
# rn18_wgtd_freeze_flip            (0.06960073858499527, 0.9772937297821045)
# rn18_wgtd_flip                    (0.06961469352245331, 0.977449893951416)
# rn18_wgtd_freeze                 (0.06966757029294968, 0.9774558544158936)
# rn18_wgtd_hist_flip               (0.0698188841342926, 0.9773477911949158)
# xrn34_wgtd_deepish               (0.06982376426458359, 0.9772156476974487)
# xrn34_wgtd_flip                   (0.06985139846801758, 0.977041482925415)
# xrn50_wgtd_deep                    (0.0699492022395134, 0.977137565612793)
# rn18_wgtd_freeze2_flip           (0.07002927362918854, 0.9775879979133606)
# xrn18_wgtd                       (0.07005224376916885, 0.9772456884384155)
# xrn50_wgtd                       (0.07005283236503601, 0.9774138331413269)
# impre-xrn34-freeze2              (0.07018836587667465, 0.9770054817199707)
# xrn50_wgtd_flip                  (0.07023485004901886, 0.9773357510566711)
# rn18_wgtd_no_pre                  (0.07035570591688156, 0.977041482925415)
# rn18_wgtd_freeze2_rep_flip       (0.07059291750192642, 0.9772276878356934)
# impre-xrn34-freeze2-deep          (0.0706302747130394, 0.9772096276283264)
# xrn50_wgtd_deep_flip              (0.0706525668501854, 0.9772636890411377)
# xrn18_wgtd_flip                  (0.07066165655851364, 0.9773117303848267)
# impre-xrn34-freeze2_flip         (0.07158342748880386, 0.9769093990325928)
# rn18_wgtd_no_pre_flip            (0.07183227688074112, 0.9767712354660034)
# impre-xrn34-freeze2-deep_flip    (0.07250490039587021, 0.9768913984298706)
# xrn34_wgtd_deepish_flip          (0.07287469506263733, 0.9765070080757141)
# dtype: object

# %%
for label in htypes:
    print('')
    print(f'feat importances for {label}')
    print('---------------------------------------------------')
    fis = sorted(zip(map(lambda x: round(x, 4), rfs[label].feature_importances_), rfs[label].feat_imp_cols),  reverse=True)
    for fi in fis:
        print(fi)
# Out:
# feat importances for any
# ---------------------------------------------------
# (0.423, 'xrn34_wgtd_deepish:any')
# (0.1413, 'xrn34_wgtd_deep:any')
# (0.139, 'rn18_wgtd_freeze2_rep:any')
# (0.1124, 'rn18_wgtd:any')
# (0.0389, 'xrn50_wgtd:any')
# (0.0169, 'rn18_wgtd_freeze2:any')
# (0.0097, 'xrn50_wgtd_flip:any')
# (0.0094, 'xrn34_wgtd_flip:any')
# (0.0078, 'rn18_wgtd_hist:any')
# (0.0071, 'xrn34_wgtd_deep_flip:any')
# (0.0071, 'rn18_wgtd_no_pre:any')
# (0.0069, 'xrn34_wgtd:any')
# (0.0065, 'xrn18_wgtd_flip:any')
# (0.0061, 'xrn50_wgtd_deep_flip:any')
# (0.0061, 'impre-xrn34-freeze2:any')
# (0.006, 'rn18_wgtd_hist_flip:any')
# (0.0058, 'xrn50_wgtd_deep:any')
# (0.0054, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0052, 'xrn18_wgtd:any')
# (0.0052, 'rn18_wgtd_freeze2_flip:any')
# (0.0052, 'rn18_wgtd_flip:any')
# (0.005, 'xrn34_wgtd_deepish_flip:any')
# (0.0044, 'rn18_wgtd_no_pre_flip:any')
# (0.0044, 'impre-xrn34-freeze2-deep:any')
# (0.0039, 'rn18_wgtd_freeze:any')
# (0.0039, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0037, 'rn18_wgtd_freeze_flip:any')
# (0.0037, 'impre-xrn34-freeze2_flip:any')
#
# feat importances for epidural
# ---------------------------------------------------
# (0.0845, 'rn18_wgtd_freeze2_flip:epidural')
# (0.0755, 'rn18_wgtd_no_pre:epidural')
# (0.058, 'rn18_wgtd_freeze_flip:epidural')
# (0.0491, 'xrn34_wgtd:epidural')
# (0.0441, 'xrn18_wgtd:epidural')
# (0.0361, 'rn18_wgtd_freeze2:epidural')
# (0.0325, 'rn18_wgtd_freeze:epidural')
# (0.0304, 'impre-xrn34-freeze2-deep_flip:epidural')
# (0.0271, 'rn18_wgtd:epidural')
# (0.027, 'rn18_wgtd_hist:epidural')
# (0.0262, 'xrn34_wgtd_deep:epidural')
# (0.0257, 'xrn34_wgtd_deep_flip:epidural')
# (0.025, 'rn18_wgtd_no_pre_flip:epidural')
# (0.0238, 'impre-xrn34-freeze2:epidural')
# (0.0235, 'xrn34_wgtd_flip:epidural')
# (0.0201, 'rn18_wgtd_hist_flip:epidural')
# (0.0201, 'rn18_wgtd_freeze2_rep:epidural')
# (0.0187, 'xrn50_wgtd:epidural')
# (0.0186, 'xrn18_wgtd_flip:epidural')
# (0.0173, 'impre-xrn34-freeze2_flip:epidural')
# (0.0173, 'impre-xrn34-freeze2-deep:epidural')
# (0.0165, 'xrn50_wgtd_flip:epidural')
# (0.015, 'xrn50_wgtd_deep:epidural')
# (0.0149, 'xrn34_wgtd_deepish:epidural')
# (0.0146, 'xrn50_wgtd:any')
# (0.0129, 'xrn34_wgtd_deepish_flip:epidural')
# (0.0116, 'xrn50_wgtd_deep_flip:epidural')
# (0.0115, 'rn18_wgtd_flip:epidural')
# (0.0113, 'rn18_wgtd_freeze2_rep_flip:epidural')
# (0.0112, 'rn18_wgtd_hist:any')
# (0.011, 'xrn34_wgtd:any')
# (0.01, 'xrn50_wgtd_deep:any')
# (0.0096, 'xrn18_wgtd:any')
# (0.0089, 'xrn50_wgtd_deep_flip:any')
# (0.0083, 'rn18_wgtd_freeze2:any')
# (0.0081, 'rn18_wgtd_hist_flip:any')
# (0.0079, 'xrn50_wgtd_flip:any')
# (0.0076, 'rn18_wgtd_no_pre_flip:any')
# (0.0074, 'rn18_wgtd_freeze:any')
# (0.0074, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0073, 'xrn34_wgtd_deepish:any')
# (0.0068, 'xrn34_wgtd_deepish_flip:any')
# (0.0067, 'rn18_wgtd_flip:any')
# (0.0066, 'xrn34_wgtd_flip:any')
# (0.0065, 'xrn34_wgtd_deep_flip:any')
# (0.0064, 'xrn34_wgtd_deep:any')
# (0.0061, 'impre-xrn34-freeze2:any')
# (0.0059, 'impre-xrn34-freeze2-deep:any')
# (0.0056, 'rn18_wgtd_no_pre:any')
# (0.0056, 'rn18_wgtd_freeze_flip:any')
# (0.0056, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0054, 'impre-xrn34-freeze2_flip:any')
# (0.0053, 'xrn18_wgtd_flip:any')
# (0.005, 'rn18_wgtd_freeze2_flip:any')
# (0.0049, 'rn18_wgtd_freeze2_rep:any')
# (0.0038, 'rn18_wgtd:any')
#
# feat importances for intraparenchymal
# ---------------------------------------------------
# (0.3375, 'rn18_wgtd_freeze2_rep:intraparenchymal')
# (0.2228, 'xrn34_wgtd_deep_flip:intraparenchymal')
# (0.0778, 'rn18_wgtd_hist:intraparenchymal')
# (0.0445, 'xrn34_wgtd_deepish:intraparenchymal')
# (0.0404, 'xrn34_wgtd_deep:intraparenchymal')
# (0.0401, 'rn18_wgtd_freeze2:intraparenchymal')
# (0.0379, 'rn18_wgtd:intraparenchymal')
# (0.0156, 'xrn50_wgtd:intraparenchymal')
# (0.0144, 'impre-xrn34-freeze2:intraparenchymal')
# (0.0136, 'xrn50_wgtd_flip:intraparenchymal')
# (0.0121, 'xrn50_wgtd_deep_flip:intraparenchymal')
# (0.012, 'rn18_wgtd_freeze2_rep_flip:intraparenchymal')
# (0.0098, 'rn18_wgtd_hist_flip:intraparenchymal')
# (0.0092, 'xrn50_wgtd_deep:intraparenchymal')
# (0.0081, 'impre-xrn34-freeze2_flip:intraparenchymal')
# (0.0077, 'impre-xrn34-freeze2-deep:intraparenchymal')
# (0.0076, 'rn18_wgtd_flip:intraparenchymal')
# (0.0062, 'xrn34_wgtd:intraparenchymal')
# (0.0048, 'rn18_wgtd_freeze_flip:intraparenchymal')
# (0.0044, 'rn18_wgtd_freeze2_flip:intraparenchymal')
# (0.0039, 'xrn34_wgtd_deepish_flip:intraparenchymal')
# (0.0037, 'xrn34_wgtd_flip:intraparenchymal')
# (0.0037, 'rn18_wgtd_freeze:intraparenchymal')
# (0.0036, 'xrn18_wgtd:intraparenchymal')
# (0.0035, 'impre-xrn34-freeze2-deep_flip:intraparenchymal')
# (0.0033, 'rn18_wgtd_no_pre:intraparenchymal')
# (0.003, 'rn18_wgtd_no_pre_flip:intraparenchymal')
# (0.0029, 'xrn18_wgtd_flip:intraparenchymal')
# (0.0019, 'xrn50_wgtd_flip:any')
# (0.0019, 'xrn34_wgtd_deepish:any')
# (0.0019, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0018, 'xrn50_wgtd_deep_flip:any')
# (0.0018, 'xrn50_wgtd_deep:any')
# (0.0018, 'xrn50_wgtd:any')
# (0.0018, 'xrn18_wgtd:any')
# (0.0018, 'rn18_wgtd_no_pre_flip:any')
# (0.0018, 'rn18_wgtd_no_pre:any')
# (0.0017, 'xrn34_wgtd_deepish_flip:any')
# (0.0017, 'xrn34_wgtd:any')
# (0.0017, 'rn18_wgtd_hist_flip:any')
# (0.0017, 'rn18_wgtd_freeze:any')
# (0.0017, 'rn18_wgtd:any')
# (0.0017, 'impre-xrn34-freeze2-deep:any')
# (0.0016, 'xrn34_wgtd_deep_flip:any')
# (0.0016, 'xrn34_wgtd_deep:any')
# (0.0016, 'xrn18_wgtd_flip:any')
# (0.0016, 'rn18_wgtd_hist:any')
# (0.0016, 'rn18_wgtd_flip:any')
# (0.0015, 'xrn34_wgtd_flip:any')
# (0.0015, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0015, 'impre-xrn34-freeze2_flip:any')
# (0.0015, 'impre-xrn34-freeze2:any')
# (0.0014, 'rn18_wgtd_freeze2_rep:any')
# (0.0013, 'rn18_wgtd_freeze_flip:any')
# (0.0013, 'rn18_wgtd_freeze2_flip:any')
# (0.0012, 'rn18_wgtd_freeze2:any')
#
# feat importances for intraventricular
# ---------------------------------------------------
# (0.358, 'xrn50_wgtd_deep:intraventricular')
# (0.2464, 'rn18_wgtd_hist:intraventricular')
# (0.1291, 'xrn50_wgtd_flip:intraventricular')
# (0.0855, 'rn18_wgtd_freeze2_rep:intraventricular')
# (0.0226, 'xrn50_wgtd:intraventricular')
# (0.0182, 'rn18_wgtd_hist_flip:intraventricular')
# (0.014, 'xrn34_wgtd_deep:intraventricular')
# (0.012, 'xrn50_wgtd_deep_flip:intraventricular')
# (0.0086, 'impre-xrn34-freeze2-deep:intraventricular')
# (0.007, 'rn18_wgtd:intraventricular')
# (0.0064, 'impre-xrn34-freeze2:intraventricular')
# (0.0051, 'impre-xrn34-freeze2_flip:intraventricular')
# (0.0049, 'xrn34_wgtd_deepish:intraventricular')
# (0.0049, 'rn18_wgtd_no_pre:intraventricular')
# (0.0039, 'rn18_wgtd_freeze2_rep_flip:intraventricular')
# (0.0038, 'rn18_wgtd_freeze:intraventricular')
# (0.0036, 'impre-xrn34-freeze2-deep_flip:intraventricular')
# (0.0034, 'xrn34_wgtd_deep_flip:intraventricular')
# (0.0029, 'rn18_wgtd_freeze_flip:intraventricular')
# (0.0029, 'rn18_wgtd_freeze2:intraventricular')
# (0.0028, 'xrn18_wgtd_flip:intraventricular')
# (0.0026, 'xrn18_wgtd:intraventricular')
# (0.0026, 'rn18_wgtd_no_pre_flip:intraventricular')
# (0.0026, 'rn18_wgtd_freeze2_flip:intraventricular')
# (0.0026, 'rn18_wgtd_flip:intraventricular')
# (0.0025, 'xrn34_wgtd_deepish_flip:intraventricular')
# (0.0025, 'xrn34_wgtd:intraventricular')
# (0.0024, 'xrn34_wgtd_flip:intraventricular')
# (0.0017, 'xrn50_wgtd_deep:any')
# (0.0017, 'xrn50_wgtd:any')
# (0.0017, 'rn18_wgtd_freeze2_rep:any')
# (0.0015, 'impre-xrn34-freeze2:any')
# (0.0014, 'xrn18_wgtd:any')
# (0.0014, 'rn18_wgtd_no_pre:any')
# (0.0014, 'rn18_wgtd_hist_flip:any')
# (0.0014, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0013, 'xrn50_wgtd_flip:any')
# (0.0013, 'xrn50_wgtd_deep_flip:any')
# (0.0013, 'xrn34_wgtd:any')
# (0.0013, 'rn18_wgtd_hist:any')
# (0.0013, 'rn18_wgtd_freeze2:any')
# (0.0013, 'rn18_wgtd:any')
# (0.0012, 'xrn34_wgtd_deepish_flip:any')
# (0.0012, 'xrn34_wgtd_deepish:any')
# (0.0012, 'xrn34_wgtd_deep_flip:any')
# (0.0012, 'xrn34_wgtd_deep:any')
# (0.0012, 'rn18_wgtd_no_pre_flip:any')
# (0.0012, 'rn18_wgtd_freeze:any')
# (0.0012, 'rn18_wgtd_flip:any')
# (0.0012, 'impre-xrn34-freeze2_flip:any')
# (0.0012, 'impre-xrn34-freeze2-deep:any')
# (0.0011, 'xrn34_wgtd_flip:any')
# (0.0011, 'xrn18_wgtd_flip:any')
# (0.0011, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0011, 'rn18_wgtd_freeze2_flip:any')
# (0.001, 'rn18_wgtd_freeze_flip:any')
#
# feat importances for subarachnoid
# ---------------------------------------------------
# (0.3375, 'xrn34_wgtd_deep:subarachnoid')
# (0.2355, 'xrn34_wgtd_deep_flip:subarachnoid')
# (0.1072, 'rn18_wgtd_freeze2:subarachnoid')
# (0.0249, 'rn18_wgtd_freeze2_rep:subarachnoid')
# (0.0214, 'xrn34_wgtd_deepish:subarachnoid')
# (0.0212, 'xrn50_wgtd_deep_flip:subarachnoid')
# (0.0157, 'xrn50_wgtd_deep:subarachnoid')
# (0.0145, 'xrn50_wgtd_flip:subarachnoid')
# (0.0131, 'xrn34_wgtd:subarachnoid')
# (0.0119, 'xrn50_wgtd:subarachnoid')
# (0.01, 'rn18_wgtd_no_pre:subarachnoid')
# (0.0094, 'rn18_wgtd_hist_flip:subarachnoid')
# (0.0089, 'xrn34_wgtd_flip:subarachnoid')
# (0.0078, 'rn18_wgtd_freeze2_rep_flip:subarachnoid')
# (0.0074, 'rn18_wgtd_freeze:subarachnoid')
# (0.0073, 'rn18_wgtd_freeze2_flip:subarachnoid')
# (0.0068, 'impre-xrn34-freeze2-deep:subarachnoid')
# (0.0063, 'rn18_wgtd_no_pre_flip:subarachnoid')
# (0.0061, 'rn18_wgtd_hist:subarachnoid')
# (0.0059, 'xrn18_wgtd_flip:subarachnoid')
# (0.0057, 'rn18_wgtd:subarachnoid')
# (0.0056, 'xrn34_wgtd_deepish_flip:subarachnoid')
# (0.0056, 'xrn18_wgtd:subarachnoid')
# (0.0054, 'rn18_wgtd_flip:subarachnoid')
# (0.0053, 'rn18_wgtd_freeze_flip:subarachnoid')
# (0.0053, 'impre-xrn34-freeze2:subarachnoid')
# (0.0052, 'impre-xrn34-freeze2-deep_flip:subarachnoid')
# (0.0051, 'impre-xrn34-freeze2_flip:subarachnoid')
# (0.0033, 'xrn50_wgtd_deep:any')
# (0.0033, 'xrn50_wgtd:any')
# (0.0032, 'xrn50_wgtd_flip:any')
# (0.0032, 'xrn50_wgtd_deep_flip:any')
# (0.0032, 'xrn34_wgtd_deepish_flip:any')
# (0.0032, 'impre-xrn34-freeze2:any')
# (0.0031, 'xrn18_wgtd:any')
# (0.0031, 'rn18_wgtd_hist_flip:any')
# (0.0029, 'xrn34_wgtd_deep:any')
# (0.0029, 'rn18_wgtd_no_pre:any')
# (0.0028, 'xrn34_wgtd:any')
# (0.0028, 'rn18_wgtd_freeze:any')
# (0.0027, 'xrn34_wgtd_deep_flip:any')
# (0.0027, 'xrn18_wgtd_flip:any')
# (0.0027, 'rn18_wgtd_hist:any')
# (0.0027, 'rn18_wgtd:any')
# (0.0027, 'impre-xrn34-freeze2_flip:any')
# (0.0027, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0026, 'xrn34_wgtd_flip:any')
# (0.0026, 'xrn34_wgtd_deepish:any')
# (0.0026, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0026, 'rn18_wgtd_flip:any')
# (0.0025, 'rn18_wgtd_freeze_flip:any')
# (0.0025, 'rn18_wgtd_freeze2_rep:any')
# (0.0025, 'impre-xrn34-freeze2-deep:any')
# (0.0024, 'rn18_wgtd_freeze2_flip:any')
# (0.0024, 'rn18_wgtd_freeze2:any')
# (0.0023, 'rn18_wgtd_no_pre_flip:any')
#
# feat importances for subdural
# ---------------------------------------------------
# (0.4376, 'xrn34_wgtd_deep:subdural')
# (0.0865, 'xrn34_wgtd_deepish:subdural')
# (0.0677, 'rn18_wgtd:subdural')
# (0.0609, 'rn18_wgtd_no_pre:subdural')
# (0.0347, 'xrn34_wgtd_deep_flip:subdural')
# (0.028, 'xrn50_wgtd:subdural')
# (0.0256, 'rn18_wgtd_freeze2:subdural')
# (0.0196, 'xrn34_wgtd:subdural')
# (0.016, 'xrn18_wgtd:subdural')
# (0.0134, 'rn18_wgtd_no_pre_flip:subdural')
# (0.0129, 'xrn18_wgtd_flip:subdural')
# (0.0095, 'xrn50_wgtd_flip:subdural')
# (0.0086, 'xrn50_wgtd_deep_flip:subdural')
# (0.0084, 'xrn50_wgtd_deep:subdural')
# (0.0071, 'xrn34_wgtd_deepish_flip:subdural')
# (0.0069, 'rn18_wgtd_hist:subdural')
# (0.0068, 'xrn34_wgtd_flip:subdural')
# (0.0065, 'rn18_wgtd_freeze2_flip:subdural')
# (0.0062, 'rn18_wgtd_hist_flip:subdural')
# (0.0061, 'impre-xrn34-freeze2:subdural')
# (0.0059, 'rn18_wgtd_freeze2_rep:subdural')
# (0.0059, 'impre-xrn34-freeze2-deep:subdural')
# (0.0058, 'rn18_wgtd_freeze:subdural')
# (0.0053, 'rn18_wgtd_flip:subdural')
# (0.0052, 'rn18_wgtd_freeze_flip:subdural')
# (0.0051, 'impre-xrn34-freeze2_flip:subdural')
# (0.0051, 'impre-xrn34-freeze2-deep_flip:subdural')
# (0.0046, 'xrn50_wgtd:any')
# (0.0046, 'rn18_wgtd_freeze2_rep_flip:subdural')
# (0.0037, 'xrn50_wgtd_flip:any')
# (0.0037, 'xrn50_wgtd_deep_flip:any')
# (0.0036, 'xrn50_wgtd_deep:any')
# (0.0035, 'xrn34_wgtd_deepish:any')
# (0.0035, 'xrn34_wgtd:any')
# (0.0034, 'rn18_wgtd_hist:any')
# (0.0034, 'rn18_wgtd:any')
# (0.0033, 'rn18_wgtd_hist_flip:any')
# (0.0032, 'xrn34_wgtd_deepish_flip:any')
# (0.0031, 'impre-xrn34-freeze2:any')
# (0.003, 'xrn34_wgtd_flip:any')
# (0.003, 'xrn34_wgtd_deep:any')
# (0.003, 'rn18_wgtd_no_pre:any')
# (0.003, 'rn18_wgtd_freeze:any')
# (0.003, 'rn18_wgtd_freeze2:any')
# (0.003, 'impre-xrn34-freeze2-deep:any')
# (0.0029, 'rn18_wgtd_no_pre_flip:any')
# (0.0029, 'rn18_wgtd_freeze2_rep:any')
# (0.0029, 'impre-xrn34-freeze2-deep_flip:any')
# (0.0028, 'xrn18_wgtd_flip:any')
# (0.0028, 'xrn18_wgtd:any')
# (0.0028, 'rn18_wgtd_freeze_flip:any')
# (0.0028, 'rn18_wgtd_freeze2_rep_flip:any')
# (0.0028, 'rn18_wgtd_flip:any')
# (0.0028, 'impre-xrn34-freeze2_flip:any')
# (0.0027, 'xrn34_wgtd_deep_flip:any')
# (0.0026, 'rn18_wgtd_freeze2_flip:any')
