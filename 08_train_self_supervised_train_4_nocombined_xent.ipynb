# %%
from rsna_retro.imports import *
from rsna_retro.metadata import *
from rsna_retro.preprocess import *
from rsna_retro.train import *
from rsna_retro.self_supervised import *
from rsna_retro.contrastive_loss import *
# Out:
# Loading imports

# %%
torch.cuda.set_device(1)

# %%
name = 'self_supervised_train_4_nocombined_xent'

# %%
dls = get_ss_data(384, splits=Meta.splits_stg1)

# %%
size=256
aug = get_aug_pipe(size, min_scale=0.4, mult=1, p_lighting=.9, p_affine=.9)
aug2 = get_aug_pipe(size, min_scale=0.3, mult=2, max_rotate=20, p_lighting=1.0, p_affine=1.0)
cb = SSCallback(BatchContrastiveLoss(XentContrastiveLoss()), size=size, aug_targ=aug, aug_pos=aug2, multi_loss=False)
learn = get_learner(dls, xresnet18, metrics=[], cbs=cb)

# %%
do_fit(learn, 8, 2e-2)
learn.save(f'runs/{name}-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.342478</td>
#       <td>4.665350</td>
#       <td>27:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.350185</td>
#       <td>5.006793</td>
#       <td>26:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.177749</td>
#       <td>4.581027</td>
#       <td>26:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.160102</td>
#       <td>4.543091</td>
#       <td>26:54</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.156007</td>
#       <td>4.543622</td>
#       <td>27:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.143010</td>
#       <td>4.521881</td>
#       <td>27:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.124783</td>
# ...

# %%
dls = get_ss_data(bs=384, splits=Meta.splits_stg1)

# %%
size=256
aug = get_aug_pipe(size, min_scale=0.7, mult=0.5)
aug2 = get_aug_pipe(size, min_scale=0.6, mult=2, max_rotate=20)
cb = SSCallback(BatchContrastiveLoss(XentContrastiveLoss()), size=size, aug_targ=aug, aug_pos=aug2, multi_loss=False)
learn = get_learner(dls, xresnet18, metrics=[], cbs=cb)

# %%
learn.load(f'runs/{name}-1')
do_fit(learn, 8, 2e-2)
learn.save(f'runs/{name}-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.280225</td>
#       <td>4.462140</td>
#       <td>27:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>27:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>27:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>27:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>27:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>27:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>13:20</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.load(f'runs/{name}-1')
do_fit(learn, 8, 2e-2)
learn.save(f'runs/{name}-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.092971</td>
#       <td>4.361059</td>
#       <td>27:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.131398</td>
#       <td>4.421393</td>
#       <td>27:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.120660</td>
#       <td>4.349236</td>
#       <td>27:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.110482</td>
#       <td>4.328004</td>
#       <td>27:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.102844</td>
#       <td>4.218756</td>
#       <td>27:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.103233</td>
#       <td>08:28</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.load(f'runs/{name}-2')
learn.dls = get_ss_data(128, splits=Meta.splits_stg1, img_dir=path_jpg)
cb.update_size(384)
do_fit(learn, 4, 1e-3)
learn.save(f'runs/{name}-3')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.072997</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c76ded8d11cd> in <module>
#       2 learn.dls = get_ss_data(128, splits=Meta.splits_stg1, img_dir=path_jpg)
#       3 cb.update_size(384)
# ----> 4 do_fit(learn, 4, 1e-3)
#       5 learn.save(f'runs/{name}-2')
#
# ~/kaggle/rsna_retro/rsna_retro/train.py in do_fit(learn, epochs, lr, freeze, do_slice, **kwargs)
#     193         learn.fit_one_cycle(1, lr, div=2, div_final=1, pct_start=0.1)
#     194     learn.unfreeze()
# --> 195     learn.fit_one_cycle(epochs, lr, **kwargs)
# ...
