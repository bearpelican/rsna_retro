# %%
from rsna_retro.imports import *
from rsna_retro.metadata import *
from rsna_retro.preprocess import *
from rsna_retro.train import *
from rsna_retro.train3d import *

# %%
torch.cuda.set_device(4)

# %%
df_any = meta.df_any
df_any.head()
# Out:
#                Modality    PatientID StudyInstanceUID SeriesInstanceUID  \
# SOPInstanceUID
# ID_2a8702d25         CT  ID_ff137633    ID_d17053848c     ID_7098f7c836
# ID_66891ac22         CT  ID_42940b2c    ID_17e33f43d0     ID_e14dd0090b
# ID_8e6e5b51f         CT  ID_76fbed32    ID_1d8eaa14ef     ID_e3919709a0
# ID_cb8b9b514         CT  ID_20039b63    ID_1cfe3e70dd     ID_e3b5d8d9b8
# ID_ee683911f         CT  ID_a065f3ac    ID_9c727ac231     ID_99e83a310d
#
#                StudyID  ImagePositionPatient  ImageOrientationPatient  \
# SOPInstanceUID
# ID_2a8702d25                     -126.437378                      1.0
# ID_66891ac22                     -125.000000                      1.0
# ID_8e6e5b51f                     -125.000000                      1.0
# ID_cb8b9b514                     -125.000000                      1.0
# ID_ee683911f                     -125.000000                      1.0
#
#                 SamplesPerPixel PhotometricInterpretation  Rows  ...  \
# ...

# %%
dbunch = get_3d_dbunch(df_any)

# %%
x,y = dbunch.one_batch()
x.shape, y.shape
# Out:
# (torch.Size([40, 3, 256, 256]), torch.Size([40, 6]))

# %% [markdown]
# ## Model

# %%
m = get_3d_head()

# %%
config=dict(custom_head=m, init=None)
learn = get_learner(dbunch, xresnet18, get_loss(), config=config)

# %%
learn.load(f'runs/baseline_any-2b', strict=False)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): ConvLayer(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): ConvLayer(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (2): ConvLayer(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): ResBlock(
#         (convs): Sequential(
#           (0): ConvLayer(
# ...

# %%
# learn.summary()

# %% [markdown]
# ## Training

# %%
name = 'train3d_baseline_18'

# %%
learn.lr_find()

# %%
do_fit(learn, 6, 3e-2, freeze=False)
learn.save(f'runs/{name}-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>accuracy_any</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.253942</td>
#       <td>04:05</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4355a239c0f8> in <module>
# ----> 1 do_fit(learn, 6, 3e-2, freeze=False)
#       2 learn.save(f'runs/{name}-1')
#
# ~/kaggle/rsna_retro/rsna_retro/train.py in do_fit(learn, epochs, lr, freeze, do_slice, **kwargs)
#      94         learn.fit_one_cycle(1, lr, div=2, div_final=1, pct_start=0.1)
#      95     learn.unfreeze()
# ---> 96     learn.fit_one_cycle(epochs, lr, **kwargs)
#      97
#      98 #Cell
#
# ...

# %%
do_fit(learn, 8, 1e-2, freeze=False)
learn.save(f'runs/{name}-2')

# %%
# OLD model with wrong split
do_fit(learn, 20, 3e-2, freeze=False)
learn.save(f'runs/{name}-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>accuracy_any</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.199542</td>
#       <td>0.226810</td>
#       <td>0.921796</td>
#       <td>0.869681</td>
#       <td>16:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.244871</td>
#       <td>0.351508</td>
#       <td>0.895710</td>
#       <td>0.766805</td>
#       <td>16:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.235130</td>
#       <td>0.469860</td>
#       <td>0.866218</td>
#       <td>0.767920</td>
#       <td>16:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.290569</td>
#       <td>0.365121</td>
#       <td>0.869017</td>
#       <td>0.684917</td>
#       <td>16:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...
